# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin00028/Decision_tree/blob/main/Decision_tree_reg_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/Advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
y
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 13.2,
#        17.4, 11.9, 17.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 17.9,
#         8.5, 16.1, 10.6, 23.2, 19.8,  9.7, 16.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 20.7, 14. , 16. , 11.3,
#        11. , 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 17.3, 11.3, 13.6, 21.7, 20.2, 12. , 16. ,
#        12.9, 16.7, 14. ,  7.3, 19.4, 22.2, 11.5, 16.9, 16.7, 20.5, 25.4,
#        17.2, 16.7, 23.8, 19.8, 19.7, 20.7, 15. ,  7.2, 12. ,  5.3, 19.8,
#        18.4, 21.8, 17.1, 20.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 16.6, 15.2, 19.7, 10.6,  6.6, 11.9, 24.7,  9.7,  1.6, 17.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
# ...

# %%
#TV vs sales
import seaborn as sns
sns.regplot(x=df['TV'],y=y,color='r')

# %%
#Radio vs sales
sns.regplot(x=df['Radio'],y=y,color='g')

# %%
#Newspaper vs sales
sns.regplot(x=df['Newspaper'],y=y,color='b')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# array([[284.3,  10.6,   6.4],
#        [184.9,  21. ,  22. ],
#        [112.9,  17.4,  38.6],
#        [ 23.8,  35.1,  65.9],
#        [290.7,   4.1,   8.5],
#        [ 19.4,  16. ,  22.3],
#        [293.6,  27.7,   1.8],
#        [ 18.7,  12.1,  23.4],
#        [134.3,   4.9,   9.3],
#        [ 25.6,  39. ,   9.3],
#        [100.4,   9.6,   3.6],
#        [ 80.2,   0. ,   9.2],
#        [188.4,  18.1,  25.6],
#        [177. ,  33.4,  38.7],
#        [125.7,  36.9,  79.2],
#        [209.6,  20.6,  10.7],
#        [142.9,  29.3,  12.6],
#        [184.9,  43.9,   1.7],
#        [222.4,   4.3,  49.8],
#        [241.7,  38. ,  23.2],
#        [ 17.2,  45.9,  69.3],
#        [120.5,  28.5,  14.2],
#        [ 89.7,   9.9,  35.7],
#        [191.1,  28.7,  18.2],
#        [ 75.5,  10.8,   6. ],
#        [193.2,  18.4,  65.7],
#        [ 85.7,  35.8,  49.3],
#        [266.9,  43.8,   5. ],
#        [ 39.5,  41.1,   5.8],
#        [261.3,  42.7,  54.7],
#        [ 13.2,  15.9,  49.6],
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([18. , 23.8, 19.8,  5.6, 23.8, 15.3, 22.6,  9.7, 17.2, 17.1,  8.5,
#         9.7, 16.7,  3.2, 12.6, 17.6,  5.6, 17.3, 11.9, 20.9, 19.8, 15.3,
#        10.8, 22.1,  9.7,  9.7, 22.6, 13.2, 11.5,  4.8, 15.5, 13.2, 23.8,
#        12. , 20.1, 20.9, 10.4, 19.8, 13.2,  6.7, 12.6, 17.6,  9.6,  9.7,
#        17.2,  9.6, 12.3, 10.1, 13.2, 14. , 13.6, 17.6,  5.6,  5.6, 11.9,
#        13.2, 13.2, 25.5,  6.6, 15.5])

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('MAE % ',mean_absolute_percentage_error(y_test,y_pred))
print('r2 score',r2_score(y_test,y_pred))
# Out:
# MAE %  0.11953208222153745
# r2 score 0.9002820318206244

# %%
df1=pd.DataFrame({'Actual value':y_test,'Predicted value':y_pred})
df1
# Out:
#     Actual value  Predicted value
# 0           16.9             18.0
# 1           22.4             23.8
# 2           21.4             19.8
# 3            7.3              5.6
# 4           24.7             23.8
# 5           12.6             15.3
# 6           22.3             22.6
# 7            8.4              9.7
# 8           16.5             17.2
# 9           16.1             17.1
# 10          11.0              8.5
# 11           8.7              9.7
# 12          16.9             16.7
# 13           5.3              3.2
# 14          10.3             12.6
# 15          16.7             17.6
# 16           5.5              5.6
# 17          16.6             17.3
# 18          11.3             11.9
# 19          18.9             20.9
# 20          19.7             19.8
# 21          12.5             15.3
# 22          10.9             10.8
# 23          22.2             22.1
# 24          11.3              9.7
# 25           8.1              9.7
# ...
